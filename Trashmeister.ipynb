# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

from tensorflow import keras
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img, array_to_img, random_zoom
from keras.layers import Flatten, Dense, Conv2D, MaxPool2D, Dropout

# %% [markdown]
# # ***Loading Dataset***

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a303abb-997c-403d-8648-47cc30d42037" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a303abb-997c-403d-8648-47cc30d42037">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Each image is of (512,396)px dimension

# %%
# !unzip trashnet.zip
# Out:
# Archive:  trashnet.zip
#    creating: trashnet/
#    creating: trashnet/cardboard/
#  extracting: trashnet/cardboard/cardboard1.jpg
#  extracting: trashnet/cardboard/cardboard10.jpg
#  extracting: trashnet/cardboard/cardboard100.jpg
#  extracting: trashnet/cardboard/cardboard101.jpg
#  extracting: trashnet/cardboard/cardboard102.jpg
#  extracting: trashnet/cardboard/cardboard103.jpg
#  extracting: trashnet/cardboard/cardboard104.jpg
#  extracting: trashnet/cardboard/cardboard105.jpg
#  extracting: trashnet/cardboard/cardboard106.jpg
#  extracting: trashnet/cardboard/cardboard107.jpg
#  extracting: trashnet/cardboard/cardboard108.jpg
#  extracting: trashnet/cardboard/cardboard109.jpg
#  extracting: trashnet/cardboard/cardboard11.jpg
#  extracting: trashnet/cardboard/cardboard110.jpg
#  extracting: trashnet/cardboard/cardboard111.jpg
#  extracting: trashnet/cardboard/cardboard112.jpg
#  extracting: trashnet/cardboard/cardboard113.jpg
#  extracting: trashnet/cardboard/cardboard114.jpg
# ...

# %% [markdown]
# Splitting the images in train test split in ratio of 8:1:1

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import splitfolders
splitfolders.ratio('trashnet', output="data", seed=1337, ratio=(0.8, 0.1,0.1))
# Out:
# Copying files: 2527 files [00:00, 5153.65 files/s]

# %%
img = mpimg.imread('data/test/glass/glass149.jpg')
plt.imshow(img)
plt.show()

# %%
train_sub_dirs = os.listdir('data/train')
random = np.random.RandomState(42)

# %%
nrows = 6
ncols = 4

count = 1

plt.figure(figsize=(nrows*4, ncols*7))

for i in range(nrows):
    p = os.path.join('data/train', train_sub_dirs[i])
    imgs = os.listdir(p)
    for i in range(ncols):
        img_path = os.path.join(p, random.choice(imgs))
        img = mpimg.imread(img_path)
        plt.subplot(nrows, ncols, count)
        plt.title(p)
        plt.imshow(img)
        count += 1

plt.show()
